# %%
produtos = {'Arroz': 15.50, 'Feijão': 8.90, 'Macarrão': 6.75}
print(produtos)
produto_caro = 0
for item in produtos:
    produto, valor = produtos
    if valor > produto_caro:
        produto_caro = valor
    print(produto)
# Out:
# {'Arroz': 15.5, 'Feijão': 8.9, 'Macarrão': 6.75}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 print(produtos)
#       3 produto_caro = 0
# ----> 4 for produto, valor in produtos:
#       5     if valor > produto_caro:
#       6         produto_caro = valor
#
# ValueError: too many values to unpack (expected 2)
